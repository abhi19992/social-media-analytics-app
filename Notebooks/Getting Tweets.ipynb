# %%
import base64
import requests

base_url = 'https://api.twitter.com/'
client_key = 'a8LPL4fwytcWXdEl0ZvxNu3KN'
client_secret = 'q42fBpSqXuBUwktRvzruW2WILXPIxkJfLVigOVyk4kA0Igw1Gl'

# %% [markdown]
# # Getting the OAuth token

# %%
key_secret = '{}:{}'.format(client_key, client_secret).encode('ascii')
b64_encoded_key = base64.b64encode(key_secret)
b64_encoded_key = b64_encoded_key.decode('ascii')

# %%
auth_url = base_url + 'oauth2/token'

# %%
auth_headers = {
    'Authorization': ('Basic '+b64_encoded_key),
    'Content-Type': 'application/x-www-form-urlencoded;charset=UTF-8'
}

auth_data = {
    'grant_type': 'client_credentials'
}

auth_resp = requests.post(auth_url, headers=auth_headers, data=auth_data)

# %%
access_token = auth_resp.json()['access_token']

# %% [markdown]
# # Searching for tweets

# %%
search_headers = {
    'Authorization': ('Bearer '+access_token)    
}

search_params = {
    'q': '#fire',
#     'result_type': 'recent',
    'count': 500
}

search_url = base_url+'1.1/search/tweets.json'

search_resp = requests.get(search_url, headers=search_headers, params=search_params)

# %%
search_resp.status_code
# Out:
# 200

# %%
search_resp.json()
# Out:
# {'statuses': [{'created_at': 'Fri Jan 17 10:24:33 +0000 2020',
#    'id': 1218116894684782592,
#    'id_str': '1218116894684782592',
#    'text': '@kikipigeon #dubai #fire as seen from Hotel https://t.co/mFy7wbeYjk',
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'dubai', 'indices': [12, 18]},
#      {'text': 'fire', 'indices': [19, 24]}],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'kikipigeon',
#       'name': 'Kiera Doherty ☀ كيرا',
#       'id': 18245672,
#       'id_str': '18245672',
#       'indices': [0, 11]}],
#     'urls': [],
#     'media': [{'id': 1218116765416337409,
#       'id_str': '1218116765416337409',
#       'indices': [44, 67],
#       'media_url': 'http://pbs.twimg.com/ext_tw_video_thumb/1218116765416337409/pu/img/4QWu0oYaeULXnfZm.jpg',
#       'media_url_https': 'https://pbs.twimg.com/ext_tw_video_thumb/1218116765416337409/pu/img/4QWu0oYaeULXnfZm.jpg',
#       'url': 'https://t.co/mFy7wbeYjk',
#       'display_url': 'pic.twitter.com/mFy7wbeYjk',
#       'expanded_url': 'https://twitter.com/83nore/status/1218116894684782592/video/1',
#       'type': 'photo',
#       'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#        'medium': {'w': 1200, 'h': 675, 'resize': 'fit'},
#        'small': {'w': 680, 'h': 383, 'resize': 'fit'},
#        'large': {'w': 1280, 'h': 720, 'resize': 'fit'}}}]},
#    'extended_entities': {'media': [{'id': 1218116765416337409,
#       'id_str': '1218116765416337409',
#       'indices': [44, 67],
#       'media_url': 'http://pbs.twimg.com/ext_tw_video_thumb/1218116765416337409/pu/img/4QWu0oYaeULXnfZm.jpg',
#       'media_url_https': 'https://pbs.twimg.com/ext_tw_video_thumb/1218116765416337409/pu/img/4QWu0oYaeULXnfZm.jpg',
#       'url': 'https://t.co/mFy7wbeYjk',
#       'display_url': 'pic.twitter.com/mFy7wbeYjk',
#       'expanded_url': 'https://twitter.com/83nore/status/1218116894684782592/video/1',
#       'type': 'video',
#       'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#        'medium': {'w': 1200, 'h': 675, 'resize': 'fit'},
#        'small': {'w': 680, 'h': 383, 'resize': 'fit'},
#        'large': {'w': 1280, 'h': 720, 'resize': 'fit'}},
#       'video_info': {'aspect_ratio': [16, 9],
#        'duration_millis': 8968,
#        'variants': [{'content_type': 'application/x-mpegURL',
#          'url': 'https://video.twimg.com/ext_tw_video/1218116765416337409/pu/pl/4h6NfPKRZr2x0Pln.m3u8?tag=10'},
#         {'bitrate': 2176000,
#          'content_type': 'video/mp4',
#          'url': 'https://video.twimg.com/ext_tw_video/1218116765416337409/pu/vid/1280x720/wTS40ikULqS6-RMW.mp4?tag=10'},
#         {'bitrate': 832000,
#          'content_type': 'video/mp4',
#          'url': 'https://video.twimg.com/ext_tw_video/1218116765416337409/pu/vid/640x360/piAXhrAwSz7tX1Lk.mp4?tag=10'},
#         {'bitrate': 256000,
#          'content_type': 'video/mp4',
#          'url': 'https://video.twimg.com/ext_tw_video/1218116765416337409/pu/vid/480x270/JswQnXw7UAJZm8jt.mp4?tag=10'}]},
#       'additional_media_info': {'monetizable': False}}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'in_reply_to_status_id': 1218108783467073536,
#    'in_reply_to_status_id_str': '1218108783467073536',
#    'in_reply_to_user_id': 18245672,
#    'in_reply_to_user_id_str': '18245672',
#    'in_reply_to_screen_name': 'kikipigeon',
#    'user': {'id': 136926326,
#     'id_str': '136926326',
#     'name': '83nore',
#     'screen_name': '83nore',
#     'location': 'Hamburg',
#     'description': 'Data Scientist in Hamburg',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 19,
#     'friends_count': 22,
#     'listed_count': 4,
#     'created_at': 'Sun Apr 25 08:34:33 +0000 2010',
#     'favourites_count': 44,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': True,
#     'verified': False,
#     'statuses_count': 73,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': '000000',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme2/bg.gif',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme2/bg.gif',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/709112044696563712/FXRwKZWX_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/709112044696563712/FXRwKZWX_normal.jpg',
#     'profile_link_color': 'ABB8C2',
#     'profile_sidebar_border_color': '000000',
#     'profile_sidebar_fill_color': '000000',
#     'profile_text_color': '000000',
#     'profile_use_background_image': False,
#     'has_extended_profile': False,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': None,
#     'follow_request_sent': None,
#     'notifications': None,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 0,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   {'created_at': 'Fri Jan 17 10:22:11 +0000 2020',
#    'id': 1218116295713075200,
#    'id_str': '1218116295713075200',
#    'text': '#fire🔥 https://t.co/nsCS2QeLqq',
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'fire', 'indices': [0, 5]}],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [{'url': 'https://t.co/nsCS2QeLqq',
#       'expanded_url': 'https://www.youtube.com/watch?v=VVV4xeWBIxE&feature=share',
#       'display_url': 'youtube.com/watch?v=VVV4xe…',
#       'indices': [7, 30]}]},
#    'metadata': {'iso_language_code': 'und', 'result_type': 'recent'},
#    'source': '<a href="http://www.facebook.com/twitter" rel="nofollow">Facebook</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1119203862,
#     'id_str': '1119203862',
#     'name': 'monica carla',
#     'screen_name': 'semerisonante',
#     'location': 'Isole Canarie, Spagna',
#     'description': 'bionutrizione&serendipità',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 45,
#     'friends_count': 143,
#     'listed_count': 0,
#     'created_at': 'Fri Jan 25 12:40:13 +0000 2013',
#     'favourites_count': 61,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 1451,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': '000000',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/3162856490/0304c64980503a6ea8737945720786e4_normal.jpeg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/3162856490/0304c64980503a6ea8737945720786e4_normal.jpeg',
#     'profile_link_color': '9266CC',
#     'profile_sidebar_border_color': '000000',
#     'profile_sidebar_fill_color': '000000',
#     'profile_text_color': '000000',
#     'profile_use_background_image': False,
#     'has_extended_profile': True,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': None,
#     'follow_request_sent': None,
#     'notifications': None,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 0,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'und'},
#   {'created_at': 'Fri Jan 17 10:21:27 +0000 2020',
#    'id': 1218116114116304896,
#    'id_str': '1218116114116304896',
#    'text': 'RT @PotholeWarriors: #ReviveAllFireHydrants in Mumbai\nThis fire hydrant seems to be recently fixed few yr old,\nBut may not b in working con…',
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'ReviveAllFireHydrants',
#       'indices': [21, 43]}],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'PotholeWarriors',
#       'name': '@PotholeWarriors🇮🇳 #RoadSafety 🏍🛵🛣',
#       'id': 914315655427481600,
#       'id_str': '914315655427481600',
#       'indices': [3, 19]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 914315655427481600,
#     'id_str': '914315655427481600',
#     'name': '@PotholeWarriors🇮🇳 #RoadSafety 🏍🛵🛣',
#     'screen_name': 'PotholeWarriors',
#     'location': 'Mumbai, India',
#     'description': 'Mission #PotholesFreeCity, #RoadSafety🚧\n #CleanMumbaiBeach🏖\nOperation #BattiGuLL💡🕯🔦\n#SaveTrees🌳Follow Us!🤝 ❤B+ve\n🎬https://t.co/x3phjqochS',
#     'url': None,
#     'entities': {'description': {'urls': [{'url': 'https://t.co/x3phjqochS',
#         'expanded_url': 'http://bit.ly/2CHKLWQ',
#         'display_url': 'bit.ly/2CHKLWQ',
#         'indices': [114, 137]}]}},
#     'protected': False,
#     'followers_count': 3395,
#     'friends_count': 4949,
#     'listed_count': 6,
#     'created_at': 'Sun Oct 01 02:26:54 +0000 2017',
#     'favourites_count': 27869,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': True,
#     'verified': False,
#     'statuses_count': 35107,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1126692507650146304/Md0iIB4u_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1126692507650146304/Md0iIB4u_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/914315655427481600/1552457475',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': None,
#     'follow_request_sent': None,
#     'notifications': None,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Fri Jan 10 04:56:22 +0000 2020',
#     'id': 1215497586531917824,
#     'id_str': '1215497586531917824',
#     'text': '#ReviveAllFireHydrants in Mumbai\nThis fire hydrant seems to be recently fixed few yr old,\nBut may not b in working… https://t.co/oSEUYHyzhL',
#     'truncated': True,
#     'entities': {'hashtags': [{'text': 'ReviveAllFireHydrants',
#        'indices': [0, 22]}],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/oSEUYHyzhL',
#        'expanded_url': 'https://twitter.com/i/web/status/1215497586531917824',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [116, 139]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 914315655427481600,
#      'id_str': '914315655427481600',
#      'name': '@PotholeWarriors🇮🇳 #RoadSafety 🏍🛵🛣',
#      'screen_name': 'PotholeWarriors',
#      'location': 'Mumbai, India',
#      'description': 'Mission #PotholesFreeCity, #RoadSafety🚧\n #CleanMumbaiBeach🏖\nOperation #BattiGuLL💡🕯🔦\n#SaveTrees🌳Follow Us!🤝 ❤B+ve\n🎬https://t.co/x3phjqochS',
#      'url': None,
#      'entities': {'description': {'urls': [{'url': 'https://t.co/x3phjqochS',
#          'expanded_url': 'http://bit.ly/2CHKLWQ',
#          'display_url': 'bit.ly/2CHKLWQ',
#          'indices': [114, 137]}]}},
#      'protected': False,
#      'followers_count': 3395,
#      'friends_count': 4949,
#      'listed_count': 6,
#      'created_at': 'Sun Oct 01 02:26:54 +0000 2017',
#      'favourites_count': 27869,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': True,
#      'verified': False,
#      'statuses_count': 35107,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': 'F5F8FA',
#      'profile_background_image_url': None,
#      'profile_background_image_url_https': None,
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1126692507650146304/Md0iIB4u_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1126692507650146304/Md0iIB4u_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/914315655427481600/1552457475',
#      'profile_link_color': '1DA1F2',
#      'profile_sidebar_border_color': 'C0DEED',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'has_extended_profile': True,
#      'default_profile': True,
#      'default_profile_image': False,
#      'following': None,
#      'follow_request_sent': None,
#      'notifications': None,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 5,
#     'favorite_count': 7,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 5,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Fri Jan 17 10:21:09 +0000 2020',
#    'id': 1218116037645869056,
#    'id_str': '1218116037645869056',
#    'text': 'RT @DKillz92: Pound Cake (Remix) by Lil Devil  \n@BBlogRT\n@TeestsElDiablo \nhttps://t.co/rzfwvZZfRS…             #unsignedartist #rap #studio…',
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'unsignedartist', 'indices': [111, 126]},
#      {'text': 'rap', 'indices': [127, 131]},
#      {'text': 'studio', 'indices': [132, 139]}],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'DKillz92',
#       'name': '🔥💯 D Killz 🔥💯',
#       'id': 1087489726565765125,
#       'id_str': '1087489726565765125',
#       'indices': [3, 12]},
#      {'screen_name': 'BBlogRT',
#       'name': 'BBlog RT',
#       'id': 363894060,
#       'id_str': '363894060',
#       'indices': [48, 56]},
#      {'screen_name': 'TeestsElDiablo',
#       'name': 'Teests El Diablo',
#       'id': 884760306664321024,
#       'id_str': '884760306664321024',
#       'indices': [57, 72]}],
#     'urls': [{'url': 'https://t.co/rzfwvZZfRS',
#       'expanded_url': 'http://m.youtube.com/watch?v=443dEK',
#       'display_url': 'm.youtube.com/watch?v=443dEK',
#       'indices': [74, 97]}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1087489726565765125,
#     'id_str': '1087489726565765125',
#     'name': '🔥💯 D Killz 🔥💯',
#     'screen_name': 'DKillz92',
#     'location': '',
#     'description': 'Music Promoter/Influencer 🗣Photographer 📸 Be sure to check out Lil Devil: https://t.co/DwhWHghOLu IG: @dkillz92',
#     'url': 'https://t.co/V0AB2s6X1E',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/V0AB2s6X1E',
#         'expanded_url': 'https://www.facebook.com/dkillz92/',
#         'display_url': 'facebook.com/dkillz92/',
#         'indices': [0, 23]}]},
#      'description': {'urls': [{'url': 'https://t.co/DwhWHghOLu',
#         'expanded_url': 'https://www.youtube.com/channel/UCSZUuyMWz4GrQxu98lrTggg',
#         'display_url': 'youtube.com/channel/UCSZUu…',
#         'indices': [74, 97]}]}},
#     'protected': False,
#     'followers_count': 26,
#     'friends_count': 58,
#     'listed_count': 0,
#     'created_at': 'Mon Jan 21 23:18:50 +0000 2019',
#     'favourites_count': 15,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 66,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': '000000',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1212515264903950336/fED49DgU_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1212515264903950336/fED49DgU_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1087489726565765125/1579252219',
#     'profile_link_color': '19CF86',
#     'profile_sidebar_border_color': '000000',
#     'profile_sidebar_fill_color': '000000',
#     'profile_text_color': '000000',
#     'profile_use_background_image': False,
#     'has_extended_profile': True,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': None,
#     'follow_request_sent': None,
#     'notifications': None,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Fri Jan 17 09:47:01 +0000 2020',
#     'id': 1218107447677767680,
#     'id_str': '1218107447677767680',
#     'text': 'Pound Cake (Remix) by Lil Devil  \n@BBlogRT\n@TeestsElDiablo \nhttps://t.co/rzfwvZZfRS…             #unsignedartist… https://t.co/knV8fYwBca',
#     'truncated': True,
#     'entities': {'hashtags': [{'text': 'unsignedartist',
#        'indices': [97, 112]}],
#      'symbols': [],
#      'user_mentions': [{'screen_name': 'BBlogRT',
#        'name': 'BBlog RT',
#        'id': 363894060,
#        'id_str': '363894060',
#        'indices': [34, 42]},
#       {'screen_name': 'TeestsElDiablo',
#        'name': 'Teests El Diablo',
#        'id': 884760306664321024,
#        'id_str': '884760306664321024',
#        'indices': [43, 58]}],
#      'urls': [{'url': 'https://t.co/rzfwvZZfRS',
#        'expanded_url': 'http://m.youtube.com/watch?v=443dEK',
#        'display_url': 'm.youtube.com/watch?v=443dEK',
#        'indices': [60, 83]},
#       {'url': 'https://t.co/knV8fYwBca',
#        'expanded_url': 'https://twitter.com/i/web/status/1218107447677767680',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [114, 137]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 1087489726565765125,
#      'id_str': '1087489726565765125',
#      'name': '🔥💯 D Killz 🔥💯',
#      'screen_name': 'DKillz92',
#      'location': '',
#      'description': 'Music Promoter/Influencer 🗣Photographer 📸 Be sure to check out Lil Devil: https://t.co/DwhWHghOLu IG: @dkillz92',
#      'url': 'https://t.co/V0AB2s6X1E',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/V0AB2s6X1E',
#          'expanded_url': 'https://www.facebook.com/dkillz92/',
#          'display_url': 'facebook.com/dkillz92/',
#          'indices': [0, 23]}]},
#       'description': {'urls': [{'url': 'https://t.co/DwhWHghOLu',
#          'expanded_url': 'https://www.youtube.com/channel/UCSZUuyMWz4GrQxu98lrTggg',
#          'display_url': 'youtube.com/channel/UCSZUu…',
#          'indices': [74, 97]}]}},
#      'protected': False,
#      'followers_count': 26,
#      'friends_count': 58,
#      'listed_count': 0,
#      'created_at': 'Mon Jan 21 23:18:50 +0000 2019',
#      'favourites_count': 15,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': False,
#      'verified': False,
#      'statuses_count': 66,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': '000000',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1212515264903950336/fED49DgU_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1212515264903950336/fED49DgU_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1087489726565765125/1579252219',
#      'profile_link_color': '19CF86',
#      'profile_sidebar_border_color': '000000',
#      'profile_sidebar_fill_color': '000000',
#      'profile_text_color': '000000',
#      'profile_use_background_image': False,
#      'has_extended_profile': True,
#      'default_profile': False,
#      'default_profile_image': False,
#      'following': None,
#      'follow_request_sent': None,
#      'notifications': None,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 2,
#     'favorite_count': 1,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 2,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   {'created_at': 'Fri Jan 17 10:20:00 +0000 2020',
#    'id': 1218115749413314560,
#    'id_str': '1218115749413314560',
#    'text': 'this will show you that #EU #Germany is like #China filters all your internet and news. #EU, #USA, #Germany,… https://t.co/FS9ad5G0dM',
#    'truncated': True,
#    'entities': {'hashtags': [{'text': 'EU', 'indices': [24, 27]},
#      {'text': 'Germany', 'indices': [28, 36]},
#      {'text': 'China', 'indices': [45, 51]},
#      {'text': 'EU', 'indices': [88, 91]},
#      {'text': 'USA', 'indices': [93, 97]},
#      {'text': 'Germany', 'indices': [99, 107]}],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [{'url': 'https://t.co/FS9ad5G0dM',
#       'expanded_url': 'https://twitter.com/i/web/status/1218115749413314560',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [110, 133]}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#    'in_reply_to_status_id': 1218115265193484293,
#    'in_reply_to_status_id_str': '1218115265193484293',
#    'in_reply_to_user_id': 840632533830238210,
#    'in_reply_to_user_id_str': '840632533830238210',
#    'in_reply_to_screen_name': 'WeltPartei',
#    'user': {'id': 840632533830238210,
#     'id_str': '840632533830238210',
#     'name': 'Welt Partei - Deutschland (Pooria Sha)',
#     'screen_name': 'WeltPartei',
#     'location': 'Deutschland/Bremen',
#     'description': '2020 = MMXX 8-8-85 (the time is now)',
#     'url': 'https://t.co/YV4k2YRoAw',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/YV4k2YRoAw',
#         'expanded_url': 'https://twitter.com/WeltPartei',
#         'display_url': 'twitter.com/WeltPartei',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 1,
#     'friends_count': 9,
#     'listed_count': 0,
#     'created_at': 'Sat Mar 11 18:36:29 +0000 2017',
#     'favourites_count': 0,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 36,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1217562574994182145/Icab_mpi_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1217562574994182145/Icab_mpi_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/840632533830238210/1579035708',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': None,
#     'follow_request_sent': None,
#     'notifications': None,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 0,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Fri Jan 17 10:19:48 +0000 2020',
#    'id': 1218115699433885696,
#    'id_str': '1218115699433885696',
#    'text': 'RT @mnbsuper: YES-NOクイズ。\n\n20年前に出されたこの問題の答えが変わるらしい。\n\n#高校生クイズ\n#関東大会\n#福澤朗\n#水戸黄門 \n#ラーメン\n#日本テレビ\n#全国高等学校クイズ選手権\n#日テレ\n#ライオン\n#トリビア \n#西武ドーム\n#西武球場\n#Fi…',
#    'truncated': False,
#    'entities': {'hashtags': [{'text': '高校生クイズ', 'indices': [52, 59]},
#      {'text': '関東大会', 'indices': [60, 65]},
#      {'text': '福澤朗', 'indices': [66, 70]},
#      {'text': '水戸黄門', 'indices': [71, 76]},
#      {'text': 'ラーメン', 'indices': [78, 83]},
#      {'text': '日本テレビ', 'indices': [84, 90]},
#      {'text': '全国高等学校クイズ選手権', 'indices': [91, 104]},
#      {'text': '日テレ', 'indices': [105, 109]},
#      {'text': 'ライオン', 'indices': [110, 115]},
#      {'text': 'トリビア', 'indices': [116, 121]},
#      {'text': '西武ドーム', 'indices': [123, 129]},
#      {'text': '西武球場', 'indices': [130, 135]}],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'mnbsuper',
#       'name': '初代・佐々木学(職業:TVディレクター)',
#       'id': 131784307,
#       'id_str': '131784307',
#       'indices': [3, 12]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'ja', 'result_type': 'recent'},
#    'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1055414249227345920,
#     'id_str': '1055414249227345920',
#     'name': 'BLUE STARS',
#     'screen_name': 'BLUESTASnihontv',
#     'location': 'Chiba City Chuo Ward, Chiba',
#     'description': '島田紳助(Green), 石坂浩二(BLUE), 桝太一(BLUE)\n福澤朗(BLUE), 羽鳥慎一(BLUE),ラルフ鈴木(BLUE)\nEXテレビ/開運! なんでも鑑定団/ZIP/ 高校生クイズ/ウルトラクイズ/ズームイン朝/ズームインサタデー/ ズームインsuper/ ハートにジャストミート/全日本プロレス中継',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 3,
#     'friends_count': 7,
#     'listed_count': 0,
#     'created_at': 'Thu Oct 25 11:02:20 +0000 2018',
#     'favourites_count': 1840,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 1856,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': '000000',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1055426965228961792/F0ya-UQZ_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1055426965228961792/F0ya-UQZ_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1055414249227345920/1540466920',
#     'profile_link_color': '1B95E0',
#     'profile_sidebar_border_color': '000000',
#     'profile_sidebar_fill_color': '000000',
#     'profile_text_color': '000000',
#     'profile_use_background_image': False,
#     'has_extended_profile': True,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': None,
#     'follow_request_sent': None,
#     'notifications': None,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Fri Jul 14 22:59:40 +0000 2017',
#     'id': 885997253294342145,
#     'id_str': '885997253294342145',
#     'text': 'YES-NOクイズ。\n\n20年前に出されたこの問題の答えが変わるらしい。\n\n#高校生クイズ\n#関東大会\n#福澤朗\n#水戸黄門 \n#ラーメン\n#日本テレビ\n#全国高等学校クイズ選手権\n#日テレ\n#ライオン\n#トリビア \n#西武ドーム… https://t.co/VpCJhQIyKx',
#     'truncated': True,
#     'entities': {'hashtags': [{'text': '高校生クイズ', 'indices': [38, 45]},
#       {'text': '関東大会', 'indices': [46, 51]},
#       {'text': '福澤朗', 'indices': [52, 56]},
#       {'text': '水戸黄門', 'indices': [57, 62]},
#       {'text': 'ラーメン', 'indices': [64, 69]},
#       {'text': '日本テレビ', 'indices': [70, 76]},
#       {'text': '全国高等学校クイズ選手権', 'indices': [77, 90]},
#       {'text': '日テレ', 'indices': [91, 95]},
#       {'text': 'ライオン', 'indices': [96, 101]},
#       {'text': 'トリビア', 'indices': [102, 107]},
#       {'text': '西武ドーム', 'indices': [109, 115]}],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/VpCJhQIyKx',
#        'expanded_url': 'https://twitter.com/i/web/status/885997253294342145',
#        'display_url': 'twitter.com/i/web/status/8…',
#        'indices': [117, 140]}]},
#     'metadata': {'iso_language_code': 'ja', 'result_type': 'recent'},
#     'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 131784307,
#      'id_str': '131784307',
#      'name': '初代・佐々木学(職業:TVディレクター)',
#      'screen_name': 'mnbsuper',
#      'location': '板橋区の大山',
#      'description': 'クイズ番組が大好き✨❔高校生クイズ❔も気になる44歳・男性・東京都板橋区在住・会社員の方です。\n地上波全国ネット番組のエンドロールにたまに名前が出たりします。\nお医者さんに言われて🍺ビールが飲めません。ハイボールを飲んでます。☕コーヒーもブラックonlyです。',
#      'url': 'https://t.co/1tEJLi4sjR',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/1tEJLi4sjR',
#          'expanded_url': 'http://nanoka.jp',
#          'display_url': 'nanoka.jp',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 1323,
#      'friends_count': 3836,
#      'listed_count': 15,
#      'created_at': 'Sun Apr 11 09:26:03 +0000 2010',
#      'favourites_count': 21449,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': True,
#      'verified': False,
#      'statuses_count': 4702,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': '000000',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/457561469635158016/H1gsbPOj_normal.png',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/457561469635158016/H1gsbPOj_normal.png',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/131784307/1360486883',
#      'profile_link_color': '0084B4',
#      'profile_sidebar_border_color': '000000',
#      'profile_sidebar_fill_color': '000000',
#      'profile_text_color': '000000',
#      'profile_use_background_image': False,
#      'has_extended_profile': True,
#      'default_profile': False,
#      'default_profile_image': False,
#      'following': None,
#      'follow_request_sent': None,
#      'notifications': None,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': {'id': '0fd33386c57b038a',
#      'url': 'https://api.twitter.com/1.1/geo/id/0fd33386c57b038a.json',
#      'place_type': 'city',
#      'name': 'Itabashi-ku',
#      'full_name': 'Itabashi-ku, Tokyo',
#      'country_code': 'JP',
#      'country': 'Japan',
#      'contained_within': [],
#      'bounding_box': {'type': 'Polygon',
#       'coordinates': [[[139.624371, 35.735759],
#         [139.722754, 35.735759],
#         [139.722754, 35.801037],
#         [139.624371, 35.801037]]]},
#      'attributes': {}},
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 26,
#     'favorite_count': 31,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'ja'},
#    'is_quote_status': False,
#    'retweet_count': 26,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'ja'},
#   {'created_at': 'Fri Jan 17 10:16:21 +0000 2020',
#    'id': 1218114828411207680,
#    'id_str': '1218114828411207680',
#    'text': 'RT @DKillz92: Pound Cake (Remix) by Lil Devil   https://t.co/rzfwvZZfRS…                #unsignedartist #rap #studio #fire #nowplaying #bea…',
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'unsignedartist', 'indices': [88, 103]},
#      {'text': 'rap', 'indices': [104, 108]},
#      {'text': 'studio', 'indices': [109, 116]},
#      {'text': 'fire', 'indices': [117, 122]},
#      {'text': 'nowplaying', 'indices': [123, 134]}],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'DKillz92',
#       'name': '🔥💯 D Killz 🔥💯',
#       'id': 1087489726565765125,
#       'id_str': '1087489726565765125',
#       'indices': [3, 12]}],
#     'urls': [{'url': 'https://t.co/rzfwvZZfRS',
#       'expanded_url': 'http://m.youtube.com/watch?v=443dEK',
#       'display_url': 'm.youtube.com/watch?v=443dEK',
#       'indices': [48, 71]}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1087489726565765125,
#     'id_str': '1087489726565765125',
#     'name': '🔥💯 D Killz 🔥💯',
#     'screen_name': 'DKillz92',
#     'location': '',
#     'description': 'Music Promoter/Influencer 🗣Photographer 📸 Be sure to check out Lil Devil: https://t.co/DwhWHghOLu IG: @dkillz92',
#     'url': 'https://t.co/V0AB2s6X1E',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/V0AB2s6X1E',
#         'expanded_url': 'https://www.facebook.com/dkillz92/',
#         'display_url': 'facebook.com/dkillz92/',
#         'indices': [0, 23]}]},
#      'description': {'urls': [{'url': 'https://t.co/DwhWHghOLu',
#         'expanded_url': 'https://www.youtube.com/channel/UCSZUuyMWz4GrQxu98lrTggg',
#         'display_url': 'youtube.com/channel/UCSZUu…',
#         'indices': [74, 97]}]}},
#     'protected': False,
#     'followers_count': 26,
#     'friends_count': 58,
#     'listed_count': 0,
#     'created_at': 'Mon Jan 21 23:18:50 +0000 2019',
#     'favourites_count': 15,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 66,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': '000000',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1212515264903950336/fED49DgU_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1212515264903950336/fED49DgU_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1087489726565765125/1579252219',
#     'profile_link_color': '19CF86',
#     'profile_sidebar_border_color': '000000',
#     'profile_sidebar_fill_color': '000000',
#     'profile_text_color': '000000',
#     'profile_use_background_image': False,
#     'has_extended_profile': True,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': None,
#     'follow_request_sent': None,
#     'notifications': None,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Fri Jan 17 07:47:56 +0000 2020',
#     'id': 1218077479144914944,
#     'id_str': '1218077479144914944',
#     'text': 'Pound Cake (Remix) by Lil Devil   https://t.co/rzfwvZZfRS…                #unsignedartist #rap #studio #fire… https://t.co/n3KsOtoukE',
#     'truncated': True,
#     'entities': {'hashtags': [{'text': 'unsignedartist', 'indices': [74, 89]},
#       {'text': 'rap', 'indices': [90, 94]},
#       {'text': 'studio', 'indices': [95, 102]},
#       {'text': 'fire', 'indices': [103, 108]}],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/rzfwvZZfRS',
#        'expanded_url': 'http://m.youtube.com/watch?v=443dEK',
#        'display_url': 'm.youtube.com/watch?v=443dEK',
#        'indices': [34, 57]},
#       {'url': 'https://t.co/n3KsOtoukE',
#        'expanded_url': 'https://twitter.com/i/web/status/1218077479144914944',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [110, 133]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 1087489726565765125,
#      'id_str': '1087489726565765125',
#      'name': '🔥💯 D Killz 🔥💯',
#      'screen_name': 'DKillz92',
#      'location': '',
#      'description': 'Music Promoter/Influencer 🗣Photographer 📸 Be sure to check out Lil Devil: https://t.co/DwhWHghOLu IG: @dkillz92',
#      'url': 'https://t.co/V0AB2s6X1E',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/V0AB2s6X1E',
#          'expanded_url': 'https://www.facebook.com/dkillz92/',
#          'display_url': 'facebook.com/dkillz92/',
#          'indices': [0, 23]}]},
#       'description': {'urls': [{'url': 'https://t.co/DwhWHghOLu',
#          'expanded_url': 'https://www.youtube.com/channel/UCSZUuyMWz4GrQxu98lrTggg',
#          'display_url': 'youtube.com/channel/UCSZUu…',
#          'indices': [74, 97]}]}},
#      'protected': False,
#      'followers_count': 26,
#      'friends_count': 58,
#      'listed_count': 0,
#      'created_at': 'Mon Jan 21 23:18:50 +0000 2019',
#      'favourites_count': 15,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': False,
#      'verified': False,
#      'statuses_count': 66,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': '000000',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1212515264903950336/fED49DgU_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1212515264903950336/fED49DgU_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1087489726565765125/1579252219',
#      'profile_link_color': '19CF86',
#      'profile_sidebar_border_color': '000000',
#      'profile_sidebar_fill_color': '000000',
#      'profile_text_color': '000000',
#      'profile_use_background_image': False,
#      'has_extended_profile': True,
#      'default_profile': False,
#      'default_profile_image': False,
#      'following': None,
#      'follow_request_sent': None,
#      'notifications': None,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 1,
#     'favorite_count': 1,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 1,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   {'created_at': 'Fri Jan 17 10:15:53 +0000 2020',
#    'id': 1218114712866623489,
#    'id_str': '1218114712866623489',
#    'text': 'RT @DKillz92: Pound Cake (Remix) by Lil Devil  \n@BBlogRT\n@UniversalRTs\n@FameRTR\n@TeestsElDiablo \nhttps://t.co/rzfwvZZfRS…             #unsi…',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'DKillz92',
#       'name': '🔥💯 D Killz 🔥💯',
#       'id': 1087489726565765125,
#       'id_str': '1087489726565765125',
#       'indices': [3, 12]},
#      {'screen_name': 'BBlogRT',
#       'name': 'BBlog RT',
#       'id': 363894060,
#       'id_str': '363894060',
#       'indices': [48, 56]},
#      {'screen_name': 'UniversalRTs',
#       'name': 'Tag for a Retweet',
#       'id': 3135896996,
#       'id_str': '3135896996',
#       'indices': [57, 70]},
#      {'screen_name': 'FameRTR',
#       'name': 'FameRTs 35.6K',
#       'id': 717487503373107201,
#       'id_str': '717487503373107201',
#       'indices': [71, 79]},
#      {'screen_name': 'TeestsElDiablo',
#       'name': 'Teests El Diablo',
#       'id': 884760306664321024,
#       'id_str': '884760306664321024',
#       'indices': [80, 95]}],
#     'urls': [{'url': 'https://t.co/rzfwvZZfRS',
#       'expanded_url': 'http://m.youtube.com/watch?v=443dEK',
#       'display_url': 'm.youtube.com/watch?v=443dEK',
#       'indices': [97, 120]}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1087489726565765125,
#     'id_str': '1087489726565765125',
#     'name': '🔥💯 D Killz 🔥💯',
#     'screen_name': 'DKillz92',
#     'location': '',
#     'description': 'Music Promoter/Influencer 🗣Photographer 📸 Be sure to check out Lil Devil: https://t.co/DwhWHghOLu IG: @dkillz92',
#     'url': 'https://t.co/V0AB2s6X1E',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/V0AB2s6X1E',
#         'expanded_url': 'https://www.facebook.com/dkillz92/',
#         'display_url': 'facebook.com/dkillz92/',
#         'indices': [0, 23]}]},
#      'description': {'urls': [{'url': 'https://t.co/DwhWHghOLu',
#         'expanded_url': 'https://www.youtube.com/channel/UCSZUuyMWz4GrQxu98lrTggg',
#         'display_url': 'youtube.com/channel/UCSZUu…',
#         'indices': [74, 97]}]}},
#     'protected': False,
#     'followers_count': 26,
#     'friends_count': 58,
#     'listed_count': 0,
#     'created_at': 'Mon Jan 21 23:18:50 +0000 2019',
#     'favourites_count': 15,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 66,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': '000000',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1212515264903950336/fED49DgU_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1212515264903950336/fED49DgU_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1087489726565765125/1579252219',
#     'profile_link_color': '19CF86',
#     'profile_sidebar_border_color': '000000',
#     'profile_sidebar_fill_color': '000000',
#     'profile_text_color': '000000',
#     'profile_use_background_image': False,
#     'has_extended_profile': True,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': None,
#     'follow_request_sent': None,
#     'notifications': None,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Fri Jan 17 10:02:11 +0000 2020',
#     'id': 1218111265207390208,
#     'id_str': '1218111265207390208',
#     'text': 'Pound Cake (Remix) by Lil Devil  \n@BBlogRT\n@UniversalRTs\n@FameRTR\n@TeestsElDiablo \nhttps://t.co/rzfwvZZfRS…… https://t.co/dfLPPwm2Ye',
#     'truncated': True,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [{'screen_name': 'BBlogRT',
#        'name': 'BBlog RT',
#        'id': 363894060,
#        'id_str': '363894060',
#        'indices': [34, 42]},
#       {'screen_name': 'UniversalRTs',
#        'name': 'Tag for a Retweet',
#        'id': 3135896996,
#        'id_str': '3135896996',
#        'indices': [43, 56]},
#       {'screen_name': 'FameRTR',
#        'name': 'FameRTs 35.6K',
#        'id': 717487503373107201,
#        'id_str': '717487503373107201',
#        'indices': [57, 65]},
#       {'screen_name': 'TeestsElDiablo',
#        'name': 'Teests El Diablo',
#        'id': 884760306664321024,
#        'id_str': '884760306664321024',
#        'indices': [66, 81]}],
#      'urls': [{'url': 'https://t.co/rzfwvZZfRS',
#        'expanded_url': 'http://m.youtube.com/watch?v=443dEK',
#        'display_url': 'm.youtube.com/watch?v=443dEK',
#        'indices': [83, 106]},
#       {'url': 'https://t.co/dfLPPwm2Ye',
#        'expanded_url': 'https://twitter.com/i/web/status/1218111265207390208',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [109, 132]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 1087489726565765125,
#      'id_str': '1087489726565765125',
#      'name': '🔥💯 D Killz 🔥💯',
#      'screen_name': 'DKillz92',
#      'location': '',
#      'description': 'Music Promoter/Influencer 🗣Photographer 📸 Be sure to check out Lil Devil: https://t.co/DwhWHghOLu IG: @dkillz92',
#      'url': 'https://t.co/V0AB2s6X1E',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/V0AB2s6X1E',
#          'expanded_url': 'https://www.facebook.com/dkillz92/',
#          'display_url': 'facebook.com/dkillz92/',
#          'indices': [0, 23]}]},
#       'description': {'urls': [{'url': 'https://t.co/DwhWHghOLu',
#          'expanded_url': 'https://www.youtube.com/channel/UCSZUuyMWz4GrQxu98lrTggg',
#          'display_url': 'youtube.com/channel/UCSZUu…',
#          'indices': [74, 97]}]}},
#      'protected': False,
#      'followers_count': 26,
#      'friends_count': 58,
#      'listed_count': 0,
#      'created_at': 'Mon Jan 21 23:18:50 +0000 2019',
#      'favourites_count': 15,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': False,
#      'verified': False,
#      'statuses_count': 66,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': '000000',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
# ...
#     'user_mentions': [],
#     'urls': []},
#    'metadata': {'iso_language_code': 'und', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'in_reply_to_status_id': 1218061823548637184,
#    'in_reply_to_status_id_str': '1218061823548637184',
#    'in_reply_to_user_id': 979680419497984000,
#    'in_reply_to_user_id_str': '979680419497984000',
#    'in_reply_to_screen_name': 'm_saltang',
#    'user': {'id': 979680419497984000,
#     'id_str': '979680419497984000',
#     'name': 'M',
#     'screen_name': 'm_saltang',
#     'location': '豆',
#     'description': 'JO1',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 11,
#     'friends_count': 40,
#     'listed_count': 0,
#     'created_at': 'Fri Mar 30 11:23:08 +0000 2018',
#     'favourites_count': 987,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 275,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1201064018133209088/7aHCjhPL_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1201064018133209088/7aHCjhPL_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/979680419497984000/1575190952',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': None,
#     'follow_request_sent': None,
#     'notifications': None,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 0,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'und'},
#   {'created_at': 'Fri Jan 17 08:51:36 +0000 2020',
#    'id': 1218093500941496321,
#    'id_str': '1218093500941496321',
#    'text': '@Royceda59 AND DARKNESS!! #Eminem #Fire #MusicToBeMurderdBy',
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'Eminem', 'indices': [26, 33]},
#      {'text': 'Fire', 'indices': [34, 39]},
#      {'text': 'MusicToBeMurderdBy', 'indices': [40, 59]}],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'Royceda59',
#       'name': 'Nickle',
#       'id': 18220386,
#       'id_str': '18220386',
#       'indices': [0, 10]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#    'in_reply_to_status_id': 1218092703101046786,
#    'in_reply_to_status_id_str': '1218092703101046786',
#    'in_reply_to_user_id': 286370584,
#    'in_reply_to_user_id_str': '286370584',
#    'in_reply_to_screen_name': 'TheRealestEazy',
#    'user': {'id': 286370584,
#     'id_str': '286370584',
#     'name': 'Eeb Wasti',
#     'screen_name': 'TheRealestEazy',
#     'location': 'Planet Earth',
#     'description': 'Lover. Gooner. Spartan. Dreamer. Michigander. 😎',
#     'url': 'https://t.co/IKoPs7DPg8',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/IKoPs7DPg8',
#         'expanded_url': 'http://www.facebook.com/wastiibr',
#         'display_url': 'facebook.com/wastiibr',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 213,
#     'friends_count': 580,
#     'listed_count': 3,
#     'created_at': 'Fri Apr 22 21:36:33 +0000 2011',
#     'favourites_count': 81268,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': True,
#     'verified': False,
#     'statuses_count': 19533,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': '7A1033',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme9/bg.gif',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme9/bg.gif',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/985217625205518337/EESH6AxU_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/985217625205518337/EESH6AxU_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/286370584/1418133836',
#     'profile_link_color': 'DA0E0E',
#     'profile_sidebar_border_color': '181A1E',
#     'profile_sidebar_fill_color': '252429',
#     'profile_text_color': '666666',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': None,
#     'follow_request_sent': None,
#     'notifications': None,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 0,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Fri Jan 17 08:49:47 +0000 2020',
#    'id': 1218093044802539521,
#    'id_str': '1218093044802539521',
#    'text': 'RT @qTO6CzN04GCIjq8: こんだけ需要あるんだから\n日プ時代のスポンサーのKIRINさん\nFIREのＣＭオファーしてください！\n需要と供給のバランスが保ててないです！！\n#KIRIN\n#FIRE https://t.co/ae19DN6CxW',
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'KIRIN', 'indices': [93, 99]},
#      {'text': 'FIRE', 'indices': [100, 105]}],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'qTO6CzN04GCIjq8',
#       'name': '１番センター豆原君🍞豆JAM',
#       'id': 772070926053548033,
#       'id_str': '772070926053548033',
#       'indices': [3, 19]}],
#     'urls': [],
#     'media': [{'id': 1218089217282019333,
#       'id_str': '1218089217282019333',
#       'indices': [106, 129],
#       'media_url': 'http://pbs.twimg.com/media/EOeFsHzUEAU3swR.jpg',
#       'media_url_https': 'https://pbs.twimg.com/media/EOeFsHzUEAU3swR.jpg',
#       'url': 'https://t.co/ae19DN6CxW',
#       'display_url': 'pic.twitter.com/ae19DN6CxW',
#       'expanded_url': 'https://twitter.com/qTO6CzN04GCIjq8/status/1218089221241491456/photo/1',
#       'type': 'photo',
#       'sizes': {'small': {'w': 209, 'h': 168, 'resize': 'fit'},
#        'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#        'medium': {'w': 209, 'h': 168, 'resize': 'fit'},
#        'large': {'w': 209, 'h': 168, 'resize': 'fit'}},
#       'source_status_id': 1218089221241491456,
#       'source_status_id_str': '1218089221241491456',
#       'source_user_id': 772070926053548033,
#       'source_user_id_str': '772070926053548033'}]},
#    'extended_entities': {'media': [{'id': 1218089217282019333,
#       'id_str': '1218089217282019333',
#       'indices': [106, 129],
#       'media_url': 'http://pbs.twimg.com/media/EOeFsHzUEAU3swR.jpg',
#       'media_url_https': 'https://pbs.twimg.com/media/EOeFsHzUEAU3swR.jpg',
#       'url': 'https://t.co/ae19DN6CxW',
#       'display_url': 'pic.twitter.com/ae19DN6CxW',
#       'expanded_url': 'https://twitter.com/qTO6CzN04GCIjq8/status/1218089221241491456/photo/1',
#       'type': 'photo',
#       'sizes': {'small': {'w': 209, 'h': 168, 'resize': 'fit'},
#        'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#        'medium': {'w': 209, 'h': 168, 'resize': 'fit'},
#        'large': {'w': 209, 'h': 168, 'resize': 'fit'}},
#       'source_status_id': 1218089221241491456,
#       'source_status_id_str': '1218089221241491456',
#       'source_user_id': 772070926053548033,
#       'source_user_id_str': '772070926053548033'},
#      {'id': 1218089219362476033,
#       'id_str': '1218089219362476033',
#       'indices': [106, 129],
#       'media_url': 'http://pbs.twimg.com/media/EOeFsPjVUAE_lS0.jpg',
#       'media_url_https': 'https://pbs.twimg.com/media/EOeFsPjVUAE_lS0.jpg',
#       'url': 'https://t.co/ae19DN6CxW',
#       'display_url': 'pic.twitter.com/ae19DN6CxW',
#       'expanded_url': 'https://twitter.com/qTO6CzN04GCIjq8/status/1218089221241491456/photo/1',
#       'type': 'photo',
#       'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#        'medium': {'w': 208, 'h': 400, 'resize': 'fit'},
#        'large': {'w': 208, 'h': 400, 'resize': 'fit'},
#        'small': {'w': 208, 'h': 400, 'resize': 'fit'}},
#       'source_status_id': 1218089221241491456,
#       'source_status_id_str': '1218089221241491456',
#       'source_user_id': 772070926053548033,
#       'source_user_id_str': '772070926053548033'}]},
#    'metadata': {'iso_language_code': 'ja', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1208024908627767296,
#     'id_str': '1208024908627767296',
#     'name': 'おんおん',
#     'screen_name': 'JO1_fightin',
#     'location': '',
#     'description': 'JO1アカウントです\n\n1picは鶴房ですが、\nみんな推してます！！',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 165,
#     'friends_count': 312,
#     'listed_count': 1,
#     'created_at': 'Fri Dec 20 14:02:46 +0000 2019',
#     'favourites_count': 815,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 295,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1208025175775596546/l3dqo7_S_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1208025175775596546/l3dqo7_S_normal.jpg',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': None,
#     'follow_request_sent': None,
#     'notifications': None,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Fri Jan 17 08:34:36 +0000 2020',
#     'id': 1218089221241491456,
#     'id_str': '1218089221241491456',
#     'text': 'こんだけ需要あるんだから\n日プ時代のスポンサーのKIRINさん\nFIREのＣＭオファーしてください！\n需要と供給のバランスが保ててないです！！\n#KIRIN\n#FIRE https://t.co/ae19DN6CxW',
#     'truncated': False,
#     'entities': {'hashtags': [{'text': 'KIRIN', 'indices': [72, 78]},
#       {'text': 'FIRE', 'indices': [79, 84]}],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [],
#      'media': [{'id': 1218089217282019333,
#        'id_str': '1218089217282019333',
#        'indices': [85, 108],
#        'media_url': 'http://pbs.twimg.com/media/EOeFsHzUEAU3swR.jpg',
#        'media_url_https': 'https://pbs.twimg.com/media/EOeFsHzUEAU3swR.jpg',
#        'url': 'https://t.co/ae19DN6CxW',
#        'display_url': 'pic.twitter.com/ae19DN6CxW',
#        'expanded_url': 'https://twitter.com/qTO6CzN04GCIjq8/status/1218089221241491456/photo/1',
#        'type': 'photo',
#        'sizes': {'small': {'w': 209, 'h': 168, 'resize': 'fit'},
#         'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#         'medium': {'w': 209, 'h': 168, 'resize': 'fit'},
#         'large': {'w': 209, 'h': 168, 'resize': 'fit'}}}]},
#     'extended_entities': {'media': [{'id': 1218089217282019333,
#        'id_str': '1218089217282019333',
#        'indices': [85, 108],
#        'media_url': 'http://pbs.twimg.com/media/EOeFsHzUEAU3swR.jpg',
#        'media_url_https': 'https://pbs.twimg.com/media/EOeFsHzUEAU3swR.jpg',
#        'url': 'https://t.co/ae19DN6CxW',
#        'display_url': 'pic.twitter.com/ae19DN6CxW',
#        'expanded_url': 'https://twitter.com/qTO6CzN04GCIjq8/status/1218089221241491456/photo/1',
#        'type': 'photo',
#        'sizes': {'small': {'w': 209, 'h': 168, 'resize': 'fit'},
#         'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#         'medium': {'w': 209, 'h': 168, 'resize': 'fit'},
#         'large': {'w': 209, 'h': 168, 'resize': 'fit'}}},
#       {'id': 1218089219362476033,
#        'id_str': '1218089219362476033',
#        'indices': [85, 108],
#        'media_url': 'http://pbs.twimg.com/media/EOeFsPjVUAE_lS0.jpg',
#        'media_url_https': 'https://pbs.twimg.com/media/EOeFsPjVUAE_lS0.jpg',
#        'url': 'https://t.co/ae19DN6CxW',
#        'display_url': 'pic.twitter.com/ae19DN6CxW',
#        'expanded_url': 'https://twitter.com/qTO6CzN04GCIjq8/status/1218089221241491456/photo/1',
#        'type': 'photo',
#        'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#         'medium': {'w': 208, 'h': 400, 'resize': 'fit'},
#         'large': {'w': 208, 'h': 400, 'resize': 'fit'},
#         'small': {'w': 208, 'h': 400, 'resize': 'fit'}}}]},
#     'metadata': {'iso_language_code': 'ja', 'result_type': 'recent'},
#     'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 772070926053548033,
#      'id_str': '772070926053548033',
#      'name': '１番センター豆原君🍞豆JAM',
#      'screen_name': 'qTO6CzN04GCIjq8',
#      'location': '',
#      'description': 'ぼく、アン(豆JAM)パン(JO1)マン(ネ)です。',
#      'url': None,
#      'entities': {'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 891,
#      'friends_count': 174,
#      'listed_count': 3,
#      'created_at': 'Sat Sep 03 13:57:08 +0000 2016',
#      'favourites_count': 10350,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': False,
#      'verified': False,
#      'statuses_count': 4510,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': 'F5F8FA',
#      'profile_background_image_url': None,
#      'profile_background_image_url_https': None,
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1216988538761142272/hNLN3cAD_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1216988538761142272/hNLN3cAD_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/772070926053548033/1578124849',
#      'profile_link_color': '1DA1F2',
#      'profile_sidebar_border_color': 'C0DEED',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'has_extended_profile': False,
#      'default_profile': True,
#      'default_profile_image': False,
#      'following': None,
#      'follow_request_sent': None,
#      'notifications': None,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 5,
#     'favorite_count': 34,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'ja'},
#    'is_quote_status': False,
#    'retweet_count': 5,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'ja'}],
#  'search_metadata': {'completed_in': 0.114,
#   'max_id': 1218116894684782592,
#   'max_id_str': '1218116894684782592',
#   'next_results': '?max_id=1218093044802539520&q=%23fire&count=100&include_entities=1',
#   'query': '%23fire',
#   'refresh_url': '?since_id=1218116894684782592&q=%23fire&include_entities=1',
#   'count': 100,
#   'since_id': 0,
#   'since_id_str': '0'}}

# %%
tweets_dict = search_resp.json()

# %%
tweets_dict.keys()
# Out:
# dict_keys(['statuses', 'search_metadata'])

# %%
len(tweets_dict['statuses'])
# Out:
# 98

# %%
tweets_dict['statuses'][0].keys()
# Out:
# dict_keys(['created_at', 'id', 'id_str', 'text', 'truncated', 'entities', 'extended_entities', 'metadata', 'source', 'in_reply_to_status_id', 'in_reply_to_status_id_str', 'in_reply_to_user_id', 'in_reply_to_user_id_str', 'in_reply_to_screen_name', 'user', 'geo', 'coordinates', 'place', 'contributors', 'is_quote_status', 'retweet_count', 'favorite_count', 'favorited', 'retweeted', 'possibly_sensitive', 'lang'])

# %%
(tweets_dict['statuses'][10])['metadata']
# Out:
# {'iso_language_code': 'en', 'result_type': 'recent'}

# %% [markdown]
# # Filterting only english tweets

# %%
filtered_tweets = []

for tweet in tweets_dict['statuses']:
    language = tweet['metadata']['iso_language_code']
    
    if(language == 'en'):
        filtered_tweets.append(tweet)

# %%
len(filtered_tweets)
# Out:
# 72

# %%
len(tweets_dict['statuses'])
# Out:
# 98

# %%
filtered_tweets[3]['entities']
# Out:
# {'hashtags': [{'text': 'EU', 'indices': [24, 27]},
#   {'text': 'Germany', 'indices': [28, 36]},
#   {'text': 'China', 'indices': [45, 51]},
#   {'text': 'EU', 'indices': [88, 91]},
#   {'text': 'USA', 'indices': [93, 97]},
#   {'text': 'Germany', 'indices': [99, 107]}],
#  'symbols': [],
#  'user_mentions': [],
#  'urls': [{'url': 'https://t.co/FS9ad5G0dM',
#    'expanded_url': 'https://twitter.com/i/web/status/1218115749413314560',
#    'display_url': 'twitter.com/i/web/status/1…',
#    'indices': [110, 133]}]}

# %%
filtered_tweets[0].keys()
# Out:
# dict_keys(['created_at', 'id', 'id_str', 'text', 'truncated', 'entities', 'extended_entities', 'metadata', 'source', 'in_reply_to_status_id', 'in_reply_to_status_id_str', 'in_reply_to_user_id', 'in_reply_to_user_id_str', 'in_reply_to_screen_name', 'user', 'geo', 'coordinates', 'place', 'contributors', 'is_quote_status', 'retweet_count', 'favorite_count', 'favorited', 'retweeted', 'possibly_sensitive', 'lang'])

# %%
filtered_tweets[10]['entities']
# Out:
# {'hashtags': [{'text': 'Bariatric', 'indices': [21, 31]},
#   {'text': 'Training', 'indices': [32, 41]}],
#  'symbols': [],
#  'user_mentions': [],
#  'urls': [{'url': 'https://t.co/kLRar3fOEK',
#    'expanded_url': 'https://twitter.com/i/web/status/1218112726922383360',
#    'display_url': 'twitter.com/i/web/status/1…',
#    'indices': [117, 140]}]}
